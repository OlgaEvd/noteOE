# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaEvd/noteOE/blob/main/11sem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Импорты

# %%
# Библиотека для работы с табличными данными
import pandas as pd

# %% [markdown]
# # Самостоятельная практика №1
#
#
# *   Прочесть с помощью pandas файл **california_housing_test.csv**, который находится в папке **sample_data**
# *   Посмотреть сколько в нем строк и столбцов
# *   (Доп) Определить какой тип данных имеют столбцы
# *   (Доп) Проверить есть ли в файле пустые значения

# %%
df = pd.read_csv('sample_data/california_housing_test.csv') #Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data

# %%
df.shape #Посмотреть сколько в нем строк и столбцов
# Out:
# (3000, 9)

# %%
df.dtypes #Определить какой тип данных имеют столбцы
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
df.isnull().sum() #Проверить есть ли в файле пустые значения
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %% [markdown]
# # Самостоятельная практика №2
#
#
# *   Показать **median_house_value** где **median_income < 2**
# *   (Доп) Показать данные в первых 2 столбцах
# *   (Доп) Выбрать данные где **housing_median_age** < 20 и **median_house_value** > 70000

# %%
df[df.median_income < 2] ['median_house_value']      #Показать median_house_value где median_income < 2
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df.columns #считать название столбцов
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df[['longitude', 'latitude']] #Показать данные в выбранных столбцах
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.query('housing_median_age < 20 and median_house_value > 70000') #Выбрать данные где housing_median_age < 20 и median_house_value > 70000
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# # Самостоятельная практика №3
#
#
#
#
# *   Определить какое максимальное и минимальное значение **median_house_value**
# * (Доп) Показать максимальное **median_house_value**, где **median_income** = 3.1250
# *  (Доп) Узнать какая максимальная **population** в зоне минимального значения **median_house_value**

# %%
print(df['median_house_value'].max()) #максимальное значение median_house_value
# Out:
# 500001.0

# %%
df['median_house_value'].min() #минимальное значение median_house_value
# Out:
# 22500.0

# %%
df[df.median_income == 3.1250] ['median_house_value'].max() #Показать максимальное median_house_value, где median_income = 3.1250
# Out:
# 233300.0

# %%
df[df.median_house_value == df['median_house_value'].min()] #максимальная population в зоне минимального значения median_house_value
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2001    -117.16     32.71                52.0        845.0           451.0
#
#       population  households  median_income  median_house_value
# 2001      1230.0       375.0         1.0918             22500.0
